# %%
import pandas as pd

filename = "parks.csv"

parkAmenities = [
    "restroom", "camping", "picnic", "playground",
    "basketball", "tennis", "volleyball", "shelter", "walking", "dogpark",
    "ampitheate", "garden", "fitness", "gazebo", "playswings", "parking"
]

try:
    df = pd.read_csv(filename)

    missing_columns = [amenity for amenity in parkAmenities if amenity not in df.columns]

    if not missing_columns:
        print("All specified amenity columns are present in the CSV!")
        
        # Print unique values for the 'restroom' and 'camping' columns as examples
        print("Unique values for 'restroom' column:", df['restroom'].unique())
        print("Unique values for 'camping' column:", df['camping'].unique())

        # Print the first 5 rows of the dataframe to get a visual sense
        print(df.head())

        # Filter rows where any column from parkAmenities has 'Yes'
        parks_with_amenities = df[df[parkAmenities].eq('Yes').any(axis=1)]
        
        # Print the filtered dataframe
        if not parks_with_amenities.empty:
            print(parks_with_amenities)
        else:
            print("No parks found with the specified amenities.")
            
    else:
        print("The following specified amenity columns are missing:", ', '.join(missing_columns))

except pd.errors.EmptyDataError:
    print(f"'{filename}' is empty!")
except pd.errors.ParserError:
    print(f"Error parsing '{filename}'. It might not be a valid CSV file.")
# Out:
# All specified amenity columns are present in the CSV!
# Unique values for 'restroom' column: ['No' 'Yes']
# Unique values for 'camping' column: ['No' 'Yes']
#   PARK_ID                    Park_name  \
# 0    CMCP          Campbell Creek Park
# 1    PENN  Charles and Ida Graham Park
# 2    FIVE             Five Points Park
# 3    ARGC   Arbor Glen Outreach Center
# 4    ABBT                  Abbott Park
#
#                                         Address          City  Zip Code  \
# 0         6601 BARCLIFF DR, CHARLOTTE, NC 28212     CHARLOTTE     28212
# 1  8101 OLIVER HAGER RD, HUNTERSVILLE, NC 28078  HUNTERSVILLE     28078
# 2            200 FRENCH ST, CHARLOTTE, NC 28216     CHARLOTTE     28216
# 3          1520 CLANTON RD, CHARLOTTE, NC 28217     CHARLOTTE     28217
# 4           1300 SPRUCE ST, CHARLOTTE, NC 28203     CHARLOTTE     28203
#
#   Park District       Phone  Longitude   Latitude  \
# 0         South  9803141003 -80.735143  35.215578
# 1         North  7047662220 -80.901609  35.427915
# 2       Central  9803141002 -80.859839  35.248357
# 3       Central  9803141110 -80.893151  35.207724
# 4       Central  9803141002 -80.870913  35.215086
#
#                                              parkurl  ... handball arts  \
# 0  https://www.mecknc.gov/parkandrec/pages/home.a...  ...       No   No
# 1  https://www.huntersville.org/162/Parks-Recreation  ...       No   No
# 2  https://www.mecknc.gov/parkandrec/pages/home.a...  ...       No   No
# 3  https://www.mecknc.gov/parkandrec/pages/home.a...  ...       No   No
# 4  https://www.mecknc.gov/parkandrec/pages/home.a...  ...       No   No
#
#   multiuser playswings parking  \
# 0        No        Yes      No
# 1        No         No      No
# 2        No        Yes     Yes
# 3        No         No     Yes
# 4        No        Yes      No
#
#                                              picture          PARK_TYPE  \
# 0                                                NaN     COMMUNITY PARK
# 1                                                NaN     COMMUNITY PARK
# 2                                                NaN  NEIGHBORHOOD PARK
# 3  https://maps.mecklenburgcountync.gov/evaluate/...                NaN
# 4                                                NaN  NEIGHBORHOOD PARK
#
#        Acres          Area       Length
# 0  20.716396  9.024026e+05  4365.287342
# 1  45.466175  1.980498e+06  7621.384535
# 2   9.257183  4.032410e+05  3542.860223
# 3        NaN           NaN          NaN
# 4   7.257750  3.161467e+05  4751.343101
#
# [5 rows x 80 columns]
#     PARK_ID                   Park_name  \
# 0      CMCP         Campbell Creek Park
# 2      FIVE            Five Points Park
# 3      ARGC  Arbor Glen Outreach Center
# 4      ABBT                 Abbott Park
# 6      CMGP            Camp Greene Park
# ..      ...                         ...
# 356    DBWP        David B. Waymer Park
# 357    CLEM            Davis Flohr Park
# 360    LOAK              Large Oak Park
# 361    ROSM        Rosedale Nature Park
# 362    MAYP        Mayerling Drive Park
#
#                                              Address          City  Zip Code  \
# 0              6601 BARCLIFF DR, CHARLOTTE, NC 28212     CHARLOTTE     28212
# 2                 200 FRENCH ST, CHARLOTTE, NC 28216     CHARLOTTE     28216
# 3               1520 CLANTON RD, CHARLOTTE, NC 28217     CHARLOTTE     28217
# 4                1300 SPRUCE ST, CHARLOTTE, NC 28203     CHARLOTTE     28203
# 6             1221 ALLEGHANY ST, CHARLOTTE, NC 28208     CHARLOTTE     28208
# ..                                               ...           ...       ...
# 356       14200 HOLBROOKS RD, HUNTERSVILLE, NC 28078  HUNTERSVILLE     28078
# 357             3020 CLEMSON AV, CHARLOTTE, NC 28205     CHARLOTTE     28205
# 360            8515 FAIRVIEW RD, CHARLOTTE, NC 28227     CHARLOTTE     28227
# 361  9519 ROSEWOOD MEADOW LN, HUNTERSVILLE, NC 28078  HUNTERSVILLE     28078
# 362           8320 MAYERLING DR, CHARLOTTE, NC 28227     CHARLOTTE     28227
#
#     Park District       Phone  Longitude   Latitude  \
# 0           South  9803141003 -80.735143  35.215578
# 2         Central  9803141002 -80.859839  35.248357
# 3         Central  9803141110 -80.893151  35.207724
# 4         Central  9803141002 -80.870913  35.215086
# 6         Central  9803141002 -80.890510  35.237370
# ..            ...         ...        ...        ...
# 356         North  7047662220 -80.834721  35.399275
# 357       Central  9803141002 -80.803175  35.241530
# 360         South  9803141003 -80.638694  35.178909
# 361         North  7047662220 -80.868553  35.410292
# 362         South  9803141003 -80.703022  35.187577
#
#                                                parkurl  ... handball arts  \
# 0    https://www.mecknc.gov/parkandrec/pages/home.a...  ...       No   No
# 2    https://www.mecknc.gov/parkandrec/pages/home.a...  ...       No   No
# 3    https://www.mecknc.gov/parkandrec/pages/home.a...  ...       No   No
# 4    https://www.mecknc.gov/parkandrec/pages/home.a...  ...       No   No
# 6    https://www.mecknc.gov/parkandrec/pages/home.a...  ...       No   No
# ..                                                 ...  ...      ...  ...
# 356  https://www.huntersville.org/162/Parks-Recreation  ...       No   No
# 357  https://www.mecknc.gov/parkandrec/pages/home.a...  ...       No   No
# 360  https://www.mecknc.gov/parkandrec/pages/home.a...  ...       No   No
# 361  https://www.huntersville.org/162/Parks-Recreation  ...       No   No
# 362  https://www.mecknc.gov/parkandrec/pages/home.a...  ...       No   No
#
#     multiuser playswings parking  \
# 0          No        Yes      No
# 2          No        Yes     Yes
# 3          No         No     Yes
# 4          No        Yes      No
# 6          No        Yes     Yes
# ..        ...        ...     ...
# 356        No        Yes     Yes
# 357        No        Yes      No
# 360        No         No     Yes
# 361        No         No     Yes
# 362        No         No      No
#
#                                                picture          PARK_TYPE  \
# 0                                                  NaN     COMMUNITY PARK
# 2                                                  NaN  NEIGHBORHOOD PARK
# 3    https://maps.mecklenburgcountync.gov/evaluate/...                NaN
# 4                                                  NaN  NEIGHBORHOOD PARK
# 6    https://maps.mecklenburgcountync.gov/evaluate/...     COMMUNITY PARK
# ..                                                 ...                ...
# 356  https://maps.mecklenburgcountync.gov/evaluate/...     COMMUNITY PARK
# 357  https://maps.mecklenburgcountync.gov/evaluate/...  NEIGHBORHOOD PARK
# 360                                                NaN                NaN
# 361                                                NaN                NaN
# 362                                                NaN  NEIGHBORHOOD PARK
#
#          Acres          Area       Length
# 0    20.716396  9.024026e+05  4365.287342
# 2     9.257183  4.032410e+05  3542.860223
# 3          NaN           NaN          NaN
# 4     7.257750  3.161467e+05  4751.343101
# 6    27.452468  1.195825e+06  6033.883706
# ..         ...           ...          ...
# 356  18.865764  8.217891e+05  6742.066142
# 357   0.909181  3.960378e+04   797.861433
# 360        NaN           NaN          NaN
# 361        NaN           NaN          NaN
# 362   5.555939  2.420158e+05  2271.858352
#
# [294 rows x 80 columns]

# %%
# Save the filtered dataframe to a new CSV file
parks_with_amenities.to_csv('filtered_parks.csv', index=False)
